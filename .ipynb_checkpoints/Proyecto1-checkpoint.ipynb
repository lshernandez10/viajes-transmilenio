# %%
import pandas as pd
import subprocess
import numpy as np

# %%
_ruta_archivo='inprocedings-json.csv' #Ruta al csv generado con OpenRefine
_ruta_salida='inprocedings-preprocessed.csv' #Ruta del archivo csv de salida
_weka="C:/Program Files/Weka-3-8/weka.jar" #Ruta al jar de weka
_arff_path=_ruta_salida.replace('.csv','.arff') #Ruta al arff de salida.

# %% [markdown]
# # Leer el archivo

# %%
_df=pd.read_csv(_ruta_archivo)
_df.columns=['paper','nombre']
#Reemplazar las comillas dobles por simples en los nombres. 
_df['nombre']=_df['nombre'].str.replace('"','-')

# %% [markdown]
# # Reducir el dataset
# Se limita el dataset a autores que tengan al menos 200 publicaciones y artículos que tengan al menos 3 de esos autores, para encontrar reglas con un soporte interesante y para sobrellevar las limitaciones de memoria

# %%
#Al menos 200 artículos
_paper_count=_df['nombre'].value_counts()
_df=_df[_df['nombre'].isin(_paper_count[_paper_count>=200].index)]
#al menos 3 de esos autores
_author_count=_df['paper'].value_counts()
_df=_df[_df['paper'].isin(_author_count[_author_count>=3].index)]

# %% [markdown]
# # Agrupar los autores por paper

# %%
_grouped=_df.groupby('paper')['nombre'].apply(lambda x: '|'.join(x)).reset_index()

# %%
_grouped
# Out:
#                                                   paper  \
# 0     http://dblp.l3s.de/d2r/resource/publications/c...
# 1     http://dblp.l3s.de/d2r/resource/publications/c...
# 2     http://dblp.l3s.de/d2r/resource/publications/c...
# 3     http://dblp.l3s.de/d2r/resource/publications/c...
# 4     http://dblp.l3s.de/d2r/resource/publications/c...
# 5     http://dblp.l3s.de/d2r/resource/publications/c...
# 6     http://dblp.l3s.de/d2r/resource/publications/c...
# 7     http://dblp.l3s.de/d2r/resource/publications/c...
# 8     http://dblp.l3s.de/d2r/resource/publications/c...
# 9     http://dblp.l3s.de/d2r/resource/publications/c...
# 10    http://dblp.l3s.de/d2r/resource/publications/c...
# 11    http://dblp.l3s.de/d2r/resource/publications/c...
# 12    http://dblp.l3s.de/d2r/resource/publications/c...
# 13    http://dblp.l3s.de/d2r/resource/publications/c...
# 14    http://dblp.l3s.de/d2r/resource/publications/c...
# 15    http://dblp.l3s.de/d2r/resource/publications/c...
# 16    http://dblp.l3s.de/d2r/resource/publications/c...
# 17    http://dblp.l3s.de/d2r/resource/publications/c...
# 18    http://dblp.l3s.de/d2r/resource/publications/c...
# 19    http://dblp.l3s.de/d2r/resource/publications/c...
# 20    http://dblp.l3s.de/d2r/resource/publications/c...
# 21    http://dblp.l3s.de/d2r/resource/publications/c...
# 22    http://dblp.l3s.de/d2r/resource/publications/c...
# 23    http://dblp.l3s.de/d2r/resource/publications/c...
# 24    http://dblp.l3s.de/d2r/resource/publications/c...
# 25    http://dblp.l3s.de/d2r/resource/publications/c...
# 26    http://dblp.l3s.de/d2r/resource/publications/c...
# 27    http://dblp.l3s.de/d2r/resource/publications/c...
# 28    http://dblp.l3s.de/d2r/resource/publications/c...
# 29    http://dblp.l3s.de/d2r/resource/publications/c...
# ...                                                 ...
# 1334  http://dblp.l3s.de/d2r/resource/publications/c...
# 1335  http://dblp.l3s.de/d2r/resource/publications/c...
# 1336  http://dblp.l3s.de/d2r/resource/publications/c...
# 1337  http://dblp.l3s.de/d2r/resource/publications/c...
# 1338  http://dblp.l3s.de/d2r/resource/publications/c...
# 1339  http://dblp.l3s.de/d2r/resource/publications/c...
# 1340  http://dblp.l3s.de/d2r/resource/publications/c...
# 1341  http://dblp.l3s.de/d2r/resource/publications/c...
# 1342  http://dblp.l3s.de/d2r/resource/publications/c...
# 1343  http://dblp.l3s.de/d2r/resource/publications/c...
# 1344  http://dblp.l3s.de/d2r/resource/publications/c...
# 1345  http://dblp.l3s.de/d2r/resource/publications/c...
# 1346  http://dblp.l3s.de/d2r/resource/publications/c...
# 1347  http://dblp.l3s.de/d2r/resource/publications/c...
# 1348  http://dblp.l3s.de/d2r/resource/publications/c...
# 1349  http://dblp.l3s.de/d2r/resource/publications/c...
# 1350  http://dblp.l3s.de/d2r/resource/publications/c...
# 1351  http://dblp.l3s.de/d2r/resource/publications/c...
# 1352  http://dblp.l3s.de/d2r/resource/publications/c...
# 1353  http://dblp.l3s.de/d2r/resource/publications/c...
# 1354  http://dblp.l3s.de/d2r/resource/publications/c...
# 1355  http://dblp.l3s.de/d2r/resource/publications/c...
# 1356  http://dblp.l3s.de/d2r/resource/publications/c...
# 1357  http://dblp.l3s.de/d2r/resource/publications/c...
# 1358  http://dblp.l3s.de/d2r/resource/publications/c...
# 1359  http://dblp.l3s.de/d2r/resource/publications/c...
# 1360  http://dblp.l3s.de/d2r/resource/publications/c...
# 1361  http://dblp.l3s.de/d2r/resource/publications/c...
# 1362  http://dblp.l3s.de/d2r/resource/publications/j...
# 1363  http://dblp.l3s.de/d2r/resource/publications/j...
#
#                                                  nombre
# 0               Mary_Jane_Irwin|Tao_Zhang|Yuan_Xie_0001
# 1                      Tao_Zhang|Yan_Chen|Yuan_Xie_0001
# 2                       Hanqing_Lu|Tieniu_Tan|Yan_Zhang
# 3           Fatos_Xhafa|Leonard_Barolli|Makoto_Takizawa
# 4           Fatos_Xhafa|Leonard_Barolli|Makoto_Takizawa
# 5                        Hui_Wang|Tao_Wang|Zhiyong_Feng
# 6                          Bo_Zhang|Xiaokang_Yang|Yi_Xu
# 7      Aboul_Ella_Hassanien|Ajith_Abraham|Václav_Snásel
# 8                            Li_Zhang|Wei_Li|Ying_Zhang
# 9                            Gang_Liu|Jian_Wang|Jun_Guo
# 10            Eduard_Ayguadé|Jesús_Labarta|Mateo_Valero
# 11            Eduard_Ayguadé|Jesús_Labarta|Mateo_Valero
# 12            Eduard_Ayguadé|Jesús_Labarta|Mateo_Valero
# 13            Eduard_Ayguadé|Jesús_Labarta|Mateo_Valero
# 14                     Chuang_Lin|Xuemin_Shen|Ying_Chen
# 15                           Jian_Wu|Ying_Li|Zhaohui_Wu
# 16                           Jian_Wu|Ying_Li|Zhaohui_Wu
# 17                        Aoying_Zhou|Minglu_Li|Ying_Li
# 18                               Bin_Wu|Jian_Wu|Ying_Li
# 19                       Chao_Wang|Fan_Zhang|Ying_Zhang
# 20                               Feng_Li|Ge_Yu|Yu_Zhang
# 21                               Feng_Li|Ge_Yu|Yu_Zhang
# 22                             Bin_Li|Yang_Wang|Yi_Wang
# 23                   C._Lee_Giles|Liang_Chen|Zhaohui_Wu
# 24                       Bo_Zhang|Qi_Tian|Shuicheng_Yan
# 25                          Hanqing_Lu|Jing_Liu|Yong_Li
# 26            Hanqing_Lu|Jing_Liu|Xiaofang_Zhou|Yi_Yang
# 27               Changsheng_Xu|Hanqing_Lu|Shuicheng_Yan
# 28              Bin_Li|Jian_Chen|Kotagiri_Ramamohanarao
# 29                        Qiang_Liu|Tieniu_Tan|Yong_Liu
# ...                                                 ...
# 1334                     Wei-Ying_Ma|Yong_Yu|Zheng_Chen
# 1335                        Hao_Wang|Xin_Zhang|Yu_Zhang
# 1336                      Jun_Li|Karsten_Schwan|Qi_Wang
# 1337     Filip_De_Turck|Piet_Demeester|Rik_Van_de_Walle
# 1338                       Dong_Li|Dong_Wang|Qian_Zhang
# 1339               Eric_P._Xing|Kai_Yu|Maarten_de_Rijke
# 1340               Dong_Wang|Qiang_Yang_0001|Zheng_Chen
# 1341               Jiawei_Han_0001|Min_Li|Xiaolong_Wang
# 1342  Jiawei_Han_0001|Jiebo_Luo|Thomas_S._Huang|Xin_Jin
# 1343                    Hai_Jin|Lionel_M._Ni|Yunhao_Liu
# 1344                HongJiang_Zhang|Wei-Ying_Ma|Yu_Chen
# 1345                     Hanqing_Lu|Hao_Liu|Wei-Ying_Ma
# 1346                       Hanqing_Lu|Jing_Liu|Xi_Zhang
# 1347        Gang_Wang|Jiawei_Han_0001|Jiebo_Luo|Xin_Jin
# 1348                   Dan_Roth|Jiawei_Han_0001|Yang_Li
# 1349                   Dong_Li|Katia_P._Sycara|Sheng_Li
# 1350       Michael_R._Lyu|Wei-Ying_Ma|Yi_Liu|Zheng_Chen
# 1351       Michael_R._Lyu|Wei-Ying_Ma|Yi_Liu|Zheng_Chen
# 1352                HongJiang_Zhang|Wei-Ying_Ma|Yu_Chen
# 1353                   Bo_Chen|Jie_Tang|Qiang_Yang_0001
# 1354                     Dong_Wang|Gang_Wang|Zheng_Chen
# 1355                           Li_Zhang|Wei_Fan|Yong_Yu
# 1356                            Bin_Li|Ling_Chen|Wei_Wu
# 1357                         Jian_Wu|Ying_Li|Zhaohui_Wu
# 1358  Edward_A._Fox|Shuicheng_Yan|Wei-Ying_Ma|Zheng_...
# 1359                     Wei-Ying_Ma|Yong_Yu|Zheng_Chen
# 1360             HongJiang_Zhang|Wei-Ying_Ma|Zheng_Chen
# 1361                  Jiawei_Han_0001|Jiebo_Luo|Xin_Jin
# 1362        Antonio_Bicchi|Paolo_Dario|Rüdiger_Dillmann
# 1363                        Hong_Chen|Qing_Wang|Yan_Liu
#
# [1364 rows x 2 columns]

# %% [markdown]
# # Obtener una columna por cada autor

# %%
#Transforma el dataset para obtener una columna binaria por cada autor. 
#Esto puede tardar bastante tiempo, dependiendo del tamaño del dataset.
_dummies=_grouped['nombre'].str.get_dummies('|')

# %%
#Agregar al dataset las columnas agrupadas
_df=pd.concat([_grouped, _dummies],axis=1)

# %% [markdown]
# # Exportar a csv

# %%
_df.to_csv(_ruta_salida, index=False, encoding='utf8' )

# %% [markdown]
# # Generar el arff a partir del csv

# %%
with open(_arff_path, "w") as arff:
    p=subprocess.Popen(['java','-classpath',_weka,"weka.core.converters.CSVLoader", _ruta_salida,"-E", '"',"-S", "1-2",'-N','3-last', '-B','56000', '-L','3-last:0,1'],stdout=arff)
    p.wait()
